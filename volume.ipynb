# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
import os
import pandas as pd

data_file = '/Users/arghavan/Graduate Center Dropbox/Arghavan Vedadi Gargari/Hydrophobic Plates/Arghavan/300K_Hbond-neighbors-AvgEnergy.xlsx'
df = pd.read_excel(data_file)
