# %% [markdown]
# # Calculating Eww using gistpp

# %%
import os
import subprocess
from decimal import Decimal


temperatures = [f"{T}" for T in range(280, 361, 20)]
distances = [f"{Decimal('0.24') + Decimal('0.02') * i:.2f}" for i in range(15,64)]

subprocess.run("module load gistpp",shell=True, capture_output=True, text=True)

refdens = {
    "260": 0.03228295317,
    "280": 0.03343042365,
    "300": 0.03331284139,
    "320": 0.03306310045,
    "340": 0.03257995556,
    "360": 0.03228279553
}

input_path = '/gibbs/arghavan/GIST_plates_with_meniscus_0.1A/'

for t in temperatures:
    output_file = f"{input_path}Eww_data/{t}K_Eww.dx"
    dens = refdens[t]

    with open(output_file, 'w') as dx_file:
        dx_file.write(f"Average Water-Water Interaction Energy at {t}K\n")
        dx_file.write(f"#Dist.(A)    #Eww(Kcal/mol)\n")
        for str_d in distances:
            d_in_angstrom = float(str_d)*10
            prefix = str(round(float(str_d)*100))
            dir_path = f"{input_path}{t}K/{str_d}/"
            os.chdir(dir_path)
        
            Eww_tot = subprocess.run(f"gistpp -i {prefix}-Eww-dens.dx -op sum", shell=True, capture_output=True, text=True)
            E_lines = Eww_tot.stdout.splitlines()
            E_sum = float(E_lines[0].split()[-1])

            gO_tot = subprocess.run(f"gistpp -i {prefix}-gO.dx -op sum", shell=True, capture_output=True, text=True)
            gO_lines = gO_tot.stdout.splitlines()
            gO_sum = float(gO_lines[0].split()[-1])

            if gO_sum != 0:
                Eww_per_molecule = E_sum/(gO_sum*dens)
                print (f'Eww_per_molecule for {d_in_angstrom:.1f} at {t}K: {Eww_per_molecule} Kcal/mol')
                dx_file.write(f"{d_in_angstrom:.1f}         {Eww_per_molecule:.15f}\n")
# Out:
# Eww_per_molecule for 5.8 at 280K: -0.6011095902419625 Kcal/mol
# Eww_per_molecule for 6.0 at 280K: -4.879165263924455 Kcal/mol
# Eww_per_molecule for 6.2 at 280K: -8.67321412125629 Kcal/mol
# Eww_per_molecule for 6.4 at 280K: -8.74771705977244 Kcal/mol
# Eww_per_molecule for 6.6 at 280K: -8.792755062316038 Kcal/mol
# Eww_per_molecule for 6.8 at 280K: -8.826298360714054 Kcal/mol
# Eww_per_molecule for 7.0 at 280K: -8.83948957950372 Kcal/mol
# Eww_per_molecule for 7.2 at 280K: -8.885344390647107 Kcal/mol
# Eww_per_molecule for 7.4 at 280K: -8.923878237810776 Kcal/mol
# Eww_per_molecule for 7.6 at 280K: -8.999494411482338 Kcal/mol
# Eww_per_molecule for 7.8 at 280K: -9.090224621294064 Kcal/mol
# Eww_per_molecule for 8.0 at 280K: -9.220744338484709 Kcal/mol
# Eww_per_molecule for 8.2 at 280K: -9.401042942282684 Kcal/mol
# Eww_per_molecule for 8.4 at 280K: -9.840897032500923 Kcal/mol
# Eww_per_molecule for 8.6 at 280K: -10.491771333117557 Kcal/mol
# Eww_per_molecule for 8.8 at 280K: -10.820545658082077 Kcal/mol
# Eww_per_molecule for 9.0 at 280K: -10.966053541675528 Kcal/mol
# Eww_per_molecule for 9.2 at 280K: -11.010946480687616 Kcal/mol
# Eww_per_molecule for 9.4 at 280K: -10.956133125130751 Kcal/mol
# Eww_per_molecule for 9.6 at 280K: -10.862408140858518 Kcal/mol
# Eww_per_molecule for 9.8 at 280K: -10.785176137523678 Kcal/mol
# Eww_per_molecule for 10.0 at 280K: -10.73373977916357 Kcal/mol
# Eww_per_molecule for 10.2 at 280K: -10.699587801837453 Kcal/mol
# Eww_per_molecule for 10.4 at 280K: -10.679622776379542 Kcal/mol
# Eww_per_molecule for 10.6 at 280K: -10.661015763790992 Kcal/mol
# Eww_per_molecule for 10.8 at 280K: -10.658420421095055 Kcal/mol
# Eww_per_molecule for 11.0 at 280K: -10.657149298021835 Kcal/mol
# Eww_per_molecule for 11.2 at 280K: -10.660585247930205 Kcal/mol
# Eww_per_molecule for 11.4 at 280K: -10.68974605817343 Kcal/mol
# Eww_per_molecule for 11.6 at 280K: -10.723061533673144 Kcal/mol
# Eww_per_molecule for 11.8 at 280K: -10.769574256492655 Kcal/mol
# Eww_per_molecule for 12.0 at 280K: -10.806292412951993 Kcal/mol
# Eww_per_molecule for 12.2 at 280K: -10.83151816500241 Kcal/mol
# Eww_per_molecule for 12.4 at 280K: -10.855918456348634 Kcal/mol
# Eww_per_molecule for 12.6 at 280K: -10.878196394007599 Kcal/mol
# Eww_per_molecule for 12.8 at 280K: -10.898207557285406 Kcal/mol
# Eww_per_molecule for 13.0 at 280K: -10.922043651714755 Kcal/mol
# Eww_per_molecule for 13.2 at 280K: -10.93903556083363 Kcal/mol
# Eww_per_molecule for 13.4 at 280K: -10.945487470309292 Kcal/mol
# Eww_per_molecule for 13.6 at 280K: -10.950826463652788 Kcal/mol
# Eww_per_molecule for 13.8 at 280K: -10.958453351159557 Kcal/mol
# Eww_per_molecule for 14.0 at 280K: -10.968471056127372 Kcal/mol
# Eww_per_molecule for 14.2 at 280K: -10.975998901229095 Kcal/mol
# Eww_per_molecule for 14.4 at 280K: -10.983316141049224 Kcal/mol
# Eww_per_molecule for 14.6 at 280K: -10.989702110748619 Kcal/mol
# Eww_per_molecule for 14.8 at 280K: -11.008890877655215 Kcal/mol
# Eww_per_molecule for 15.0 at 280K: -11.028317275940914 Kcal/mol
# Eww_per_molecule for 5.8 at 300K: -0.6696084358302009 Kcal/mol
# Eww_per_molecule for 6.0 at 300K: -4.83971554366976 Kcal/mol
# Eww_per_molecule for 6.2 at 300K: -8.397474729601374 Kcal/mol
# Eww_per_molecule for 6.4 at 300K: -8.510102414733149 Kcal/mol
# Eww_per_molecule for 6.6 at 300K: -8.555583365461173 Kcal/mol
# Eww_per_molecule for 6.8 at 300K: -8.586027736623837 Kcal/mol
# Eww_per_molecule for 7.0 at 300K: -8.621380140210537 Kcal/mol
# Eww_per_molecule for 7.2 at 300K: -8.649337965960836 Kcal/mol
# Eww_per_molecule for 7.4 at 300K: -8.688746849519106 Kcal/mol
# Eww_per_molecule for 7.6 at 300K: -8.747655110396998 Kcal/mol
# Eww_per_molecule for 7.8 at 300K: -8.814881929064791 Kcal/mol
# Eww_per_molecule for 8.0 at 300K: -8.91610219209854 Kcal/mol
# Eww_per_molecule for 8.2 at 300K: -9.070253460832774 Kcal/mol
# Eww_per_molecule for 8.4 at 300K: -9.369614229857769 Kcal/mol
# Eww_per_molecule for 8.6 at 300K: -9.984420732240148 Kcal/mol
# Eww_per_molecule for 8.8 at 300K: -10.40020703454603 Kcal/mol
# Eww_per_molecule for 9.0 at 300K: -10.552265290347137 Kcal/mol
# Eww_per_molecule for 9.2 at 300K: -10.59046724223535 Kcal/mol
# Eww_per_molecule for 9.4 at 300K: -10.568149138532954 Kcal/mol
# Eww_per_molecule for 9.6 at 300K: -10.51392306597557 Kcal/mol
# Eww_per_molecule for 9.8 at 300K: -10.471665719555983 Kcal/mol
# Eww_per_molecule for 10.0 at 300K: -10.426530823474442 Kcal/mol
# Eww_per_molecule for 10.2 at 300K: -10.393306110699122 Kcal/mol
# Eww_per_molecule for 10.4 at 300K: -10.377088807565073 Kcal/mol
# Eww_per_molecule for 10.6 at 300K: -10.359727971345619 Kcal/mol
# Eww_per_molecule for 10.8 at 300K: -10.352094732778673 Kcal/mol
# Eww_per_molecule for 11.0 at 300K: -10.349607166804589 Kcal/mol
# Eww_per_molecule for 11.2 at 300K: -10.352148258772042 Kcal/mol
# Eww_per_molecule for 11.4 at 300K: -10.383402650706438 Kcal/mol
# Eww_per_molecule for 11.6 at 300K: -10.418315242503478 Kcal/mol
# Eww_per_molecule for 11.8 at 300K: -10.457879543615714 Kcal/mol
# Eww_per_molecule for 12.0 at 300K: -10.490622488023073 Kcal/mol
# Eww_per_molecule for 12.2 at 300K: -10.530395691713013 Kcal/mol
# Eww_per_molecule for 12.4 at 300K: -10.550157456178715 Kcal/mol
# Eww_per_molecule for 12.6 at 300K: -10.57839666950144 Kcal/mol
# Eww_per_molecule for 12.8 at 300K: -10.603536482882653 Kcal/mol
# Eww_per_molecule for 13.0 at 300K: -10.618668136979595 Kcal/mol
# Eww_per_molecule for 13.2 at 300K: -10.640048556941803 Kcal/mol
# Eww_per_molecule for 13.4 at 300K: -10.646602182781749 Kcal/mol
# Eww_per_molecule for 13.6 at 300K: -10.654230049220029 Kcal/mol
# Eww_per_molecule for 13.8 at 300K: -10.664474457450831 Kcal/mol
# Eww_per_molecule for 14.0 at 300K: -10.665187306237488 Kcal/mol
# Eww_per_molecule for 14.2 at 300K: -10.677985337576711 Kcal/mol
# Eww_per_molecule for 14.4 at 300K: -10.686909374059475 Kcal/mol
# Eww_per_molecule for 14.6 at 300K: -10.697894964505991 Kcal/mol
# Eww_per_molecule for 14.8 at 300K: -10.713303020233067 Kcal/mol
# Eww_per_molecule for 15.0 at 300K: -10.725108029282154 Kcal/mol
# Eww_per_molecule for 5.8 at 320K: -0.4621252752705179 Kcal/mol
# Eww_per_molecule for 6.0 at 320K: -3.435201517143357 Kcal/mol
# Eww_per_molecule for 6.2 at 320K: -8.03269537987878 Kcal/mol
# Eww_per_molecule for 6.4 at 320K: -8.26300800593182 Kcal/mol
# Eww_per_molecule for 6.6 at 320K: -8.319784934909388 Kcal/mol
# Eww_per_molecule for 6.8 at 320K: -8.357832593581179 Kcal/mol
# Eww_per_molecule for 7.0 at 320K: -8.386517067901302 Kcal/mol
# Eww_per_molecule for 7.2 at 320K: -8.411327635763982 Kcal/mol
# Eww_per_molecule for 7.4 at 320K: -8.438559428810109 Kcal/mol
# Eww_per_molecule for 7.6 at 320K: -8.489430399339446 Kcal/mol
# Eww_per_molecule for 7.8 at 320K: -8.548246840498088 Kcal/mol
# Eww_per_molecule for 8.0 at 320K: -8.6384981700733 Kcal/mol
# Eww_per_molecule for 8.2 at 320K: -8.756906385234814 Kcal/mol
# Eww_per_molecule for 8.4 at 320K: -8.978272151750964 Kcal/mol
# Eww_per_molecule for 8.6 at 320K: -9.482047091524544 Kcal/mol
# Eww_per_molecule for 8.8 at 320K: -9.959835852510796 Kcal/mol
# Eww_per_molecule for 9.0 at 320K: -10.160728766162206 Kcal/mol
# Eww_per_molecule for 9.2 at 320K: -10.224352436612435 Kcal/mol
# Eww_per_molecule for 9.4 at 320K: -10.21674391486755 Kcal/mol
# Eww_per_molecule for 9.6 at 320K: -10.186540016305697 Kcal/mol
# Eww_per_molecule for 9.8 at 320K: -10.14540660780693 Kcal/mol
# Eww_per_molecule for 10.0 at 320K: -10.105025762075794 Kcal/mol
# Eww_per_molecule for 10.2 at 320K: -10.086969311956983 Kcal/mol
# Eww_per_molecule for 10.4 at 320K: -10.069022007828966 Kcal/mol
# Eww_per_molecule for 10.6 at 320K: -10.053256481262773 Kcal/mol
# Eww_per_molecule for 10.8 at 320K: -10.051412542514534 Kcal/mol
# Eww_per_molecule for 11.0 at 320K: -10.057660275449223 Kcal/mol
# Eww_per_molecule for 11.2 at 320K: -10.051233493183599 Kcal/mol
# Eww_per_molecule for 11.4 at 320K: -10.081220923130331 Kcal/mol
# Eww_per_molecule for 11.6 at 320K: -10.108163781729049 Kcal/mol
# Eww_per_molecule for 11.8 at 320K: -10.152568316543169 Kcal/mol
# Eww_per_molecule for 12.0 at 320K: -10.187921316129561 Kcal/mol
# Eww_per_molecule for 12.2 at 320K: -10.217342800722903 Kcal/mol
# Eww_per_molecule for 12.4 at 320K: -10.253501912987183 Kcal/mol
# Eww_per_molecule for 12.6 at 320K: -10.280674266918036 Kcal/mol
# Eww_per_molecule for 12.8 at 320K: -10.30005928776725 Kcal/mol
# Eww_per_molecule for 13.0 at 320K: -10.320156074700195 Kcal/mol
# Eww_per_molecule for 13.2 at 320K: -10.336725732549606 Kcal/mol
# Eww_per_molecule for 13.4 at 320K: -10.343814387171284 Kcal/mol
# Eww_per_molecule for 13.6 at 320K: -10.348783805927317 Kcal/mol
# Eww_per_molecule for 13.8 at 320K: -10.362689154784382 Kcal/mol
# Eww_per_molecule for 14.0 at 320K: -10.375306487264705 Kcal/mol
# Eww_per_molecule for 14.2 at 320K: -10.379007871164674 Kcal/mol
# Eww_per_molecule for 14.4 at 320K: -10.391584223688593 Kcal/mol
# Eww_per_molecule for 14.6 at 320K: -10.40460773261494 Kcal/mol
# Eww_per_molecule for 14.8 at 320K: -10.414280395662498 Kcal/mol
# Eww_per_molecule for 15.0 at 320K: -10.43202556578812 Kcal/mol
# Eww_per_molecule for 5.6 at 340K: 0.06802216627833696 Kcal/mol
# Eww_per_molecule for 5.8 at 340K: -0.5483734075268681 Kcal/mol
# Eww_per_molecule for 6.0 at 340K: -2.7510262523138342 Kcal/mol
# Eww_per_molecule for 6.2 at 340K: -7.41373584853253 Kcal/mol
# Eww_per_molecule for 6.4 at 340K: -7.995317610247886 Kcal/mol
# Eww_per_molecule for 6.6 at 340K: -8.07650196788503 Kcal/mol
# Eww_per_molecule for 6.8 at 340K: -8.113628870417802 Kcal/mol
# Eww_per_molecule for 7.0 at 340K: -8.14931440942467 Kcal/mol
# Eww_per_molecule for 7.2 at 340K: -8.166646024000352 Kcal/mol
# Eww_per_molecule for 7.4 at 340K: -8.194331472868111 Kcal/mol
# Eww_per_molecule for 7.6 at 340K: -8.23116829714456 Kcal/mol
# Eww_per_molecule for 7.8 at 340K: -8.28469645950495 Kcal/mol
# Eww_per_molecule for 8.0 at 340K: -8.353010622399099 Kcal/mol
# Eww_per_molecule for 8.2 at 340K: -8.457568503416029 Kcal/mol
# Eww_per_molecule for 8.4 at 340K: -8.623417183516922 Kcal/mol
# Eww_per_molecule for 8.6 at 340K: -9.030652547668112 Kcal/mol
# Eww_per_molecule for 8.8 at 340K: -9.491896205945379 Kcal/mol
# Eww_per_molecule for 9.0 at 340K: -9.759666678158542 Kcal/mol
# Eww_per_molecule for 9.2 at 340K: -9.847676161288422 Kcal/mol
# Eww_per_molecule for 9.4 at 340K: -9.863257586745311 Kcal/mol
# Eww_per_molecule for 9.6 at 340K: -9.839271660268668 Kcal/mol
# Eww_per_molecule for 9.8 at 340K: -9.821772543811916 Kcal/mol
# Eww_per_molecule for 10.0 at 340K: -9.797868191445296 Kcal/mol
# Eww_per_molecule for 10.2 at 340K: -9.771388873794857 Kcal/mol
# Eww_per_molecule for 10.4 at 340K: -9.762379054429756 Kcal/mol
# Eww_per_molecule for 10.6 at 340K: -9.750794032083306 Kcal/mol
# Eww_per_molecule for 10.8 at 340K: -9.747324056137717 Kcal/mol
# Eww_per_molecule for 11.0 at 340K: -9.745961466349561 Kcal/mol
# Eww_per_molecule for 11.2 at 340K: -9.765316943591365 Kcal/mol
# Eww_per_molecule for 11.4 at 340K: -9.779928379488817 Kcal/mol
# Eww_per_molecule for 11.6 at 340K: -9.810503170053316 Kcal/mol
# Eww_per_molecule for 11.8 at 340K: -9.84515597647945 Kcal/mol
# Eww_per_molecule for 12.0 at 340K: -9.881558503767412 Kcal/mol
# Eww_per_molecule for 12.2 at 340K: -9.918537871380092 Kcal/mol
# Eww_per_molecule for 12.4 at 340K: -9.950951327341054 Kcal/mol
# Eww_per_molecule for 12.6 at 340K: -9.976539807414772 Kcal/mol
# Eww_per_molecule for 12.8 at 340K: -9.998002437242267 Kcal/mol
# Eww_per_molecule for 13.0 at 340K: -10.019778072827206 Kcal/mol
# Eww_per_molecule for 13.2 at 340K: -10.035999140180452 Kcal/mol
# Eww_per_molecule for 13.4 at 340K: -10.048921624316892 Kcal/mol
# Eww_per_molecule for 13.6 at 340K: -10.06044429672573 Kcal/mol
# Eww_per_molecule for 13.8 at 340K: -10.064352265814556 Kcal/mol
# Eww_per_molecule for 14.0 at 340K: -10.076407780265965 Kcal/mol
# Eww_per_molecule for 14.2 at 340K: -10.087654617268596 Kcal/mol
# Eww_per_molecule for 14.4 at 340K: -10.099419786923688 Kcal/mol
# Eww_per_molecule for 14.6 at 340K: -10.112174324322089 Kcal/mol
# Eww_per_molecule for 14.8 at 340K: -10.119370917675035 Kcal/mol
# Eww_per_molecule for 15.0 at 340K: -10.135502850425329 Kcal/mol
# Eww_per_molecule for 5.6 at 360K: -0.36901679542209376 Kcal/mol
# Eww_per_molecule for 5.8 at 360K: -0.6524598593255052 Kcal/mol
# Eww_per_molecule for 6.0 at 360K: -2.097485315465237 Kcal/mol
# Eww_per_molecule for 6.2 at 360K: -6.498802783422223 Kcal/mol
# Eww_per_molecule for 6.4 at 360K: -7.67915906191819 Kcal/mol
# Eww_per_molecule for 6.6 at 360K: -7.803256338830729 Kcal/mol
# Eww_per_molecule for 6.8 at 360K: -7.858482342085783 Kcal/mol
# Eww_per_molecule for 7.0 at 360K: -7.884742661066292 Kcal/mol
# Eww_per_molecule for 7.2 at 360K: -7.910267038958637 Kcal/mol
# Eww_per_molecule for 7.4 at 360K: -7.934450476430716 Kcal/mol
# Eww_per_molecule for 7.6 at 360K: -7.967557956438682 Kcal/mol
# Eww_per_molecule for 7.8 at 360K: -8.01316970209556 Kcal/mol
# Eww_per_molecule for 8.0 at 360K: -8.077719270302117 Kcal/mol
# Eww_per_molecule for 8.2 at 360K: -8.161538322376305 Kcal/mol
# Eww_per_molecule for 8.4 at 360K: -8.314565703993095 Kcal/mol
# Eww_per_molecule for 8.6 at 360K: -8.614333192580535 Kcal/mol
# Eww_per_molecule for 8.8 at 360K: -9.03341219562094 Kcal/mol
# Eww_per_molecule for 9.0 at 360K: -9.33595039599804 Kcal/mol
# Eww_per_molecule for 9.2 at 360K: -9.460378938929985 Kcal/mol
# Eww_per_molecule for 9.4 at 360K: -9.504523206111758 Kcal/mol
# Eww_per_molecule for 9.6 at 360K: -9.50460765291538 Kcal/mol
# Eww_per_molecule for 9.8 at 360K: -9.483411150816888 Kcal/mol
# Eww_per_molecule for 10.0 at 360K: -9.477872268220647 Kcal/mol
# Eww_per_molecule for 10.2 at 360K: -9.472435759281291 Kcal/mol
# Eww_per_molecule for 10.4 at 360K: -9.460723586442448 Kcal/mol
# Eww_per_molecule for 10.6 at 360K: -9.456168452330475 Kcal/mol
# Eww_per_molecule for 10.8 at 360K: -9.450069473343623 Kcal/mol
# Eww_per_molecule for 11.0 at 360K: -9.46154120568643 Kcal/mol
# Eww_per_molecule for 11.2 at 360K: -9.472234433520006 Kcal/mol
# Eww_per_molecule for 11.4 at 360K: -9.486887094346038 Kcal/mol
# Eww_per_molecule for 11.6 at 360K: -9.505875239948267 Kcal/mol
# Eww_per_molecule for 11.8 at 360K: -9.548336343977793 Kcal/mol
# Eww_per_molecule for 12.0 at 360K: -9.583266728762561 Kcal/mol
# Eww_per_molecule for 12.2 at 360K: -9.623400617316403 Kcal/mol
# Eww_per_molecule for 12.4 at 360K: -9.648158133359908 Kcal/mol
# Eww_per_molecule for 12.6 at 360K: -9.681741322904621 Kcal/mol
# Eww_per_molecule for 12.8 at 360K: -9.698372691506592 Kcal/mol
# Eww_per_molecule for 13.0 at 360K: -9.721194927809114 Kcal/mol
# Eww_per_molecule for 13.2 at 360K: -9.734576878322269 Kcal/mol
# Eww_per_molecule for 13.4 at 360K: -9.751978172962026 Kcal/mol
# Eww_per_molecule for 13.6 at 360K: -9.762992817753151 Kcal/mol
# Eww_per_molecule for 13.8 at 360K: -9.776841234858143 Kcal/mol
# Eww_per_molecule for 14.0 at 360K: -9.788603192798664 Kcal/mol
# Eww_per_molecule for 14.2 at 360K: -9.800119109898617 Kcal/mol
# Eww_per_molecule for 14.4 at 360K: -9.802800923878053 Kcal/mol
# Eww_per_molecule for 14.6 at 360K: -9.823643788823631 Kcal/mol
# Eww_per_molecule for 14.8 at 360K: -9.83013488512422 Kcal/mol
# Eww_per_molecule for 15.0 at 360K: -9.842483230683632 Kcal/mol

# %% [markdown]
# # Esw

# %%
import os
import subprocess
from decimal import Decimal


temperatures = [f"{T}" for T in range(260, 361, 20)]
distances = [f"{Decimal('0.24') + Decimal('0.02') * i:.2f}" for i in range(15,64)]

subprocess.run("module load gistpp",shell=True, capture_output=True, text=True)

refdens = {
    "260": 0.03228295317,
    "280": 0.03343042365,
    "300": 0.03331284139,
    "320": 0.03306310045,
    "340": 0.03257995556,
    "360": 0.03228279553
}

input_path = '/gibbs/arghavan/GIST_plates_with_meniscus_0.1A/'

for t in temperatures:
    output_file = f"{input_path}sw_data/{t}K_Esw.dx"
    dens = refdens[t]

    with open(output_file, 'w') as dx_file:
        dx_file.write(f"Average Solute-Water Interaction Energy at {t}K\n")
        dx_file.write(f"#Dist.(A)    #Esw(Kcal/mol)\n")

        for str_d in distances:

            d_in_angstrom = float(str_d)*10
            prefix = str(round(float(str_d)*100))
            dir_path = f"{input_path}{t}K/{str_d}/"
            os.chdir(dir_path)
        
            Esw_tot = subprocess.run(f"gistpp -i {prefix}-Esw-dens.dx -op sum", shell=True, capture_output=True, text=True)
            E_lines = Esw_tot.stdout.splitlines()
            E_sum = float(E_lines[0].split()[-1])

            gO_tot = subprocess.run(f"gistpp -i {prefix}-gO.dx -op sum", shell=True, capture_output=True, text=True)
            gO_lines = gO_tot.stdout.splitlines()
            gO_sum = float(gO_lines[0].split()[-1])

            if gO_sum != 0:
                Esw_per_molecule = E_sum/(gO_sum*dens)
                print (f'Esw for {d_in_angstrom:.1f} at {t}K: {Esw_per_molecule} Kcal/mol')
                dx_file.write(f"{d_in_angstrom:.1f}         {Esw_per_molecule:.15f}\n")
# Out:
# Esw for 5.6 at 260K: -0.07647150418334815 Kcal/mol
# Esw for 5.8 at 260K: -1.175686948795043 Kcal/mol
# Esw for 6.0 at 260K: -2.3704826337120974 Kcal/mol
# Esw for 6.2 at 260K: -2.6596937386987434 Kcal/mol
# Esw for 6.4 at 260K: -2.7125303413564916 Kcal/mol
# Esw for 6.6 at 260K: -2.6608972239902315 Kcal/mol
# Esw for 6.8 at 260K: -2.5497654302717327 Kcal/mol
# Esw for 7.0 at 260K: -2.412490155441425 Kcal/mol
# Esw for 7.2 at 260K: -2.2685241299262464 Kcal/mol
# Esw for 7.4 at 260K: -2.129858018477183 Kcal/mol
# Esw for 7.6 at 260K: -1.9980381619443728 Kcal/mol
# Esw for 7.8 at 260K: -1.8806714066329275 Kcal/mol
# Esw for 8.0 at 260K: -1.776659224235591 Kcal/mol
# Esw for 8.2 at 260K: -1.6713390177122376 Kcal/mol
# Esw for 8.4 at 260K: -1.5222980426513624 Kcal/mol
# Esw for 8.6 at 260K: -1.4840239849906824 Kcal/mol
# Esw for 8.8 at 260K: -1.519542334813293 Kcal/mol
# Esw for 9.0 at 260K: -1.557179330270186 Kcal/mol
# Esw for 9.2 at 260K: -1.559829908972394 Kcal/mol
# Esw for 9.4 at 260K: -1.5211986955282097 Kcal/mol
# Esw for 9.6 at 260K: -1.4554820878498949 Kcal/mol
# Esw for 9.8 at 260K: -1.372741502951792 Kcal/mol
# Esw for 10.0 at 260K: -1.300926780760721 Kcal/mol
# Esw for 10.2 at 260K: -1.2393893983273507 Kcal/mol
# Esw for 10.4 at 260K: -1.185869534211051 Kcal/mol
# Esw for 10.6 at 260K: -1.1419665472475773 Kcal/mol
# Esw for 10.8 at 260K: -1.1023579554309324 Kcal/mol
# Esw for 11.0 at 260K: -1.071414485805236 Kcal/mol
# Esw for 11.2 at 260K: -1.04651705975539 Kcal/mol
# Esw for 11.4 at 260K: -1.0274206925076577 Kcal/mol
# Esw for 11.6 at 260K: -1.0137466318505173 Kcal/mol
# Esw for 11.8 at 260K: -0.9988615401628383 Kcal/mol
# Esw for 12.0 at 260K: -0.9810629320422778 Kcal/mol
# Esw for 12.2 at 260K: -0.9601135936157706 Kcal/mol
# Esw for 12.4 at 260K: -0.9379048032002171 Kcal/mol
# Esw for 12.6 at 260K: -0.9170359779245645 Kcal/mol
# Esw for 12.8 at 260K: -0.8983446438802237 Kcal/mol
# Esw for 13.0 at 260K: -0.8801431037924486 Kcal/mol
# Esw for 13.2 at 260K: -0.8617200163492849 Kcal/mol
# Esw for 13.4 at 260K: -0.8428317585257574 Kcal/mol
# Esw for 13.6 at 260K: -0.8240975602589237 Kcal/mol
# Esw for 13.8 at 260K: -0.8043192245690821 Kcal/mol
# Esw for 14.0 at 260K: -0.7862676368727669 Kcal/mol
# Esw for 14.2 at 260K: -0.7689083559904794 Kcal/mol
# Esw for 14.4 at 260K: -0.7526715777474838 Kcal/mol
# Esw for 14.6 at 260K: -0.7398011748077994 Kcal/mol
# Esw for 14.8 at 260K: -0.7285300708455306 Kcal/mol
# Esw for 15.0 at 260K: -0.7187903729351421 Kcal/mol
# Esw for 5.8 at 280K: -1.9847227000298708 Kcal/mol
# Esw for 6.0 at 280K: -2.4074305092947657 Kcal/mol
# Esw for 6.2 at 280K: -2.643031934416739 Kcal/mol
# Esw for 6.4 at 280K: -2.699245596937682 Kcal/mol
# Esw for 6.6 at 280K: -2.648871137628907 Kcal/mol
# Esw for 6.8 at 280K: -2.540454134556265 Kcal/mol
# Esw for 7.0 at 280K: -2.405182299408711 Kcal/mol
# Esw for 7.2 at 280K: -2.262985245200029 Kcal/mol
# Esw for 7.4 at 280K: -2.124233199486885 Kcal/mol
# Esw for 7.6 at 280K: -1.9971266130137415 Kcal/mol
# Esw for 7.8 at 280K: -1.8811196775693486 Kcal/mol
# Esw for 8.0 at 280K: -1.7770379209685179 Kcal/mol
# Esw for 8.2 at 280K: -1.677760984921543 Kcal/mol
# Esw for 8.4 at 280K: -1.5583186398945938 Kcal/mol
# Esw for 8.6 at 280K: -1.4890728747606667 Kcal/mol
# Esw for 8.8 at 280K: -1.516238666838624 Kcal/mol
# Esw for 9.0 at 280K: -1.5398835398528277 Kcal/mol
# Esw for 9.2 at 280K: -1.5331622502858389 Kcal/mol
# Esw for 9.4 at 280K: -1.489692880578677 Kcal/mol
# Esw for 9.6 at 280K: -1.4259443162908703 Kcal/mol
# Esw for 9.8 at 280K: -1.3571021393151024 Kcal/mol
# Esw for 10.0 at 280K: -1.291040510473081 Kcal/mol
# Esw for 10.2 at 280K: -1.232359386738944 Kcal/mol
# Esw for 10.4 at 280K: -1.181941070367831 Kcal/mol
# Esw for 10.6 at 280K: -1.135920148804304 Kcal/mol
# Esw for 10.8 at 280K: -1.098778336872173 Kcal/mol
# Esw for 11.0 at 280K: -1.0655996841533693 Kcal/mol
# Esw for 11.2 at 280K: -1.039115468649558 Kcal/mol
# Esw for 11.4 at 280K: -1.0191708762442693 Kcal/mol
# Esw for 11.6 at 280K: -1.0040309400416063 Kcal/mol
# Esw for 11.8 at 280K: -0.9891409753873945 Kcal/mol
# Esw for 12.0 at 280K: -0.9712434831210914 Kcal/mol
# Esw for 12.2 at 280K: -0.9509933634998363 Kcal/mol
# Esw for 12.4 at 280K: -0.9289746235750485 Kcal/mol
# Esw for 12.6 at 280K: -0.9077539311723066 Kcal/mol
# Esw for 12.8 at 280K: -0.8884050810899375 Kcal/mol
# Esw for 13.0 at 280K: -0.8703651250305574 Kcal/mol
# Esw for 13.2 at 280K: -0.8517303807431709 Kcal/mol
# Esw for 13.4 at 280K: -0.833203480468369 Kcal/mol
# Esw for 13.6 at 280K: -0.8144714382330719 Kcal/mol
# Esw for 13.8 at 280K: -0.7951681715986786 Kcal/mol
# Esw for 14.0 at 280K: -0.7784635099689202 Kcal/mol
# Esw for 14.2 at 280K: -0.7618508578559052 Kcal/mol
# Esw for 14.4 at 280K: -0.7462525822062916 Kcal/mol
# Esw for 14.6 at 280K: -0.7325767863250514 Kcal/mol
# Esw for 14.8 at 280K: -0.7208240818214222 Kcal/mol
# Esw for 15.0 at 280K: -0.7102947433363342 Kcal/mol
# Esw for 5.8 at 300K: -2.0992736888098653 Kcal/mol
# Esw for 6.0 at 300K: -2.5053989768899534 Kcal/mol
# Esw for 6.2 at 300K: -2.6273449118212344 Kcal/mol
# Esw for 6.4 at 300K: -2.684268912754089 Kcal/mol
# Esw for 6.6 at 300K: -2.6360217058308915 Kcal/mol
# Esw for 6.8 at 300K: -2.5307863271514104 Kcal/mol
# Esw for 7.0 at 300K: -2.396477035949312 Kcal/mol
# Esw for 7.2 at 300K: -2.2577614104148096 Kcal/mol
# Esw for 7.4 at 300K: -2.1214390997245864 Kcal/mol
# Esw for 7.6 at 300K: -1.9927774748638338 Kcal/mol
# Esw for 7.8 at 300K: -1.8787946749069317 Kcal/mol
# Esw for 8.0 at 300K: -1.7760242498082288 Kcal/mol
# Esw for 8.2 at 300K: -1.6789979765601282 Kcal/mol
# Esw for 8.4 at 300K: -1.57467315861105 Kcal/mol
# Esw for 8.6 at 300K: -1.500003847704677 Kcal/mol
# Esw for 8.8 at 300K: -1.508924298049373 Kcal/mol
# Esw for 9.0 at 300K: -1.522703277504662 Kcal/mol
# Esw for 9.2 at 300K: -1.5105871260547747 Kcal/mol
# Esw for 9.4 at 300K: -1.468955961736531 Kcal/mol
# Esw for 9.6 at 300K: -1.4091108181839 Kcal/mol
# Esw for 9.8 at 300K: -1.345968575745312 Kcal/mol
# Esw for 10.0 at 300K: -1.2838584266295696 Kcal/mol
# Esw for 10.2 at 300K: -1.2269669043680769 Kcal/mol
# Esw for 10.4 at 300K: -1.1755320040539807 Kcal/mol
# Esw for 10.6 at 300K: -1.1331000501997746 Kcal/mol
# Esw for 10.8 at 300K: -1.0942012356408266 Kcal/mol
# Esw for 11.0 at 300K: -1.0606783665949502 Kcal/mol
# Esw for 11.2 at 300K: -1.0320559294037832 Kcal/mol
# Esw for 11.4 at 300K: -1.0117682967194892 Kcal/mol
# Esw for 11.6 at 300K: -0.9937122647339571 Kcal/mol
# Esw for 11.8 at 300K: -0.9774378345838632 Kcal/mol
# Esw for 12.0 at 300K: -0.9594871671399631 Kcal/mol
# Esw for 12.2 at 300K: -0.9396644888512314 Kcal/mol
# Esw for 12.4 at 300K: -0.9194332822366914 Kcal/mol
# Esw for 12.6 at 300K: -0.8991924292884057 Kcal/mol
# Esw for 12.8 at 300K: -0.8787796239168516 Kcal/mol
# Esw for 13.0 at 300K: -0.8594795454035813 Kcal/mol
# Esw for 13.2 at 300K: -0.8418602266230942 Kcal/mol
# Esw for 13.4 at 300K: -0.8240503876280029 Kcal/mol
# Esw for 13.6 at 300K: -0.8055303318988748 Kcal/mol
# Esw for 13.8 at 300K: -0.7869510718875797 Kcal/mol
# Esw for 14.0 at 300K: -0.7695060916899048 Kcal/mol
# Esw for 14.2 at 300K: -0.7537667008948924 Kcal/mol
# Esw for 14.4 at 300K: -0.7379126674570926 Kcal/mol
# Esw for 14.6 at 300K: -0.7252087196574963 Kcal/mol
# Esw for 14.8 at 300K: -0.7129765470732252 Kcal/mol
# Esw for 15.0 at 300K: -0.7023073425008635 Kcal/mol
# Esw for 5.8 at 320K: -2.0947964056431636 Kcal/mol
# Esw for 6.0 at 320K: -2.276899549447972 Kcal/mol
# Esw for 6.2 at 320K: -2.6127731073357663 Kcal/mol
# Esw for 6.4 at 320K: -2.6704010910800093 Kcal/mol
# Esw for 6.6 at 320K: -2.6227646689890154 Kcal/mol
# Esw for 6.8 at 320K: -2.5200730553818516 Kcal/mol
# Esw for 7.0 at 320K: -2.390354448871684 Kcal/mol
# Esw for 7.2 at 320K: -2.251227892186128 Kcal/mol
# Esw for 7.4 at 320K: -2.1148087296098845 Kcal/mol
# Esw for 7.6 at 320K: -1.989282756230787 Kcal/mol
# Esw for 7.8 at 320K: -1.876398575781881 Kcal/mol
# Esw for 8.0 at 320K: -1.7738866517751855 Kcal/mol
# Esw for 8.2 at 320K: -1.6791767860331028 Kcal/mol
# Esw for 8.4 at 320K: -1.5817569207019992 Kcal/mol
# Esw for 8.6 at 320K: -1.508132611319895 Kcal/mol
# Esw for 8.8 at 320K: -1.4981110816205248 Kcal/mol
# Esw for 9.0 at 320K: -1.5068745652878073 Kcal/mol
# Esw for 9.2 at 320K: -1.4918356146175231 Kcal/mol
# Esw for 9.4 at 320K: -1.4526045533511316 Kcal/mol
# Esw for 9.6 at 320K: -1.3946733380979823 Kcal/mol
# Esw for 9.8 at 320K: -1.3337519496119752 Kcal/mol
# Esw for 10.0 at 320K: -1.2749427504966104 Kcal/mol
# Esw for 10.2 at 320K: -1.2188023089920823 Kcal/mol
# Esw for 10.4 at 320K: -1.1712920123982988 Kcal/mol
# Esw for 10.6 at 320K: -1.1275136807283286 Kcal/mol
# Esw for 10.8 at 320K: -1.0891872747500912 Kcal/mol
# Esw for 11.0 at 320K: -1.0556674366563799 Kcal/mol
# Esw for 11.2 at 320K: -1.0268929759971908 Kcal/mol
# Esw for 11.4 at 320K: -1.0023369733088887 Kcal/mol
# Esw for 11.6 at 320K: -0.9831373761713949 Kcal/mol
# Esw for 11.8 at 320K: -0.9670105948065075 Kcal/mol
# Esw for 12.0 at 320K: -0.9493124606340394 Kcal/mol
# Esw for 12.2 at 320K: -0.9291982641316856 Kcal/mol
# Esw for 12.4 at 320K: -0.9092744511238757 Kcal/mol
# Esw for 12.6 at 320K: -0.8894357285878434 Kcal/mol
# Esw for 12.8 at 320K: -0.8688550213754275 Kcal/mol
# Esw for 13.0 at 320K: -0.8504685267199907 Kcal/mol
# Esw for 13.2 at 320K: -0.8307236531718143 Kcal/mol
# Esw for 13.4 at 320K: -0.8140059117731318 Kcal/mol
# Esw for 13.6 at 320K: -0.7941738606679067 Kcal/mol
# Esw for 13.8 at 320K: -0.7781665214663676 Kcal/mol
# Esw for 14.0 at 320K: -0.7610698228417413 Kcal/mol
# Esw for 14.2 at 320K: -0.7447239386265285 Kcal/mol
# Esw for 14.4 at 320K: -0.7293631703377068 Kcal/mol
# Esw for 14.6 at 320K: -0.7178420555747991 Kcal/mol
# Esw for 14.8 at 320K: -0.7043264914900993 Kcal/mol
# Esw for 15.0 at 320K: -0.6934639246192226 Kcal/mol
# Esw for 5.6 at 340K: -1.2975282120260307 Kcal/mol
# Esw for 5.8 at 340K: -1.7548189052563703 Kcal/mol
# Esw for 6.0 at 340K: -2.360390259738393 Kcal/mol
# Esw for 6.2 at 340K: -2.596504263154557 Kcal/mol
# Esw for 6.4 at 340K: -2.6588453706361173 Kcal/mol
# Esw for 6.6 at 340K: -2.6160667261782504 Kcal/mol
# Esw for 6.8 at 340K: -2.510831040097199 Kcal/mol
# Esw for 7.0 at 340K: -2.3819909092078686 Kcal/mol
# Esw for 7.2 at 340K: -2.24440479137552 Kcal/mol
# Esw for 7.4 at 340K: -2.1119598553966257 Kcal/mol
# Esw for 7.6 at 340K: -1.9844985945529883 Kcal/mol
# Esw for 7.8 at 340K: -1.8734298234657656 Kcal/mol
# Esw for 8.0 at 340K: -1.770036607136425 Kcal/mol
# Esw for 8.2 at 340K: -1.6753548154514866 Kcal/mol
# Esw for 8.4 at 340K: -1.5859081043398733 Kcal/mol
# Esw for 8.6 at 340K: -1.5122919536822361 Kcal/mol
# Esw for 8.8 at 340K: -1.4893384221013874 Kcal/mol
# Esw for 9.0 at 340K: -1.4920163680156948 Kcal/mol
# Esw for 9.2 at 340K: -1.4730447739974128 Kcal/mol
# Esw for 9.4 at 340K: -1.4332625267794792 Kcal/mol
# Esw for 9.6 at 340K: -1.3797817203482077 Kcal/mol
# Esw for 9.8 at 340K: -1.3219377130352492 Kcal/mol
# Esw for 10.0 at 340K: -1.2650825747446737 Kcal/mol
# Esw for 10.2 at 340K: -1.2129802623669423 Kcal/mol
# Esw for 10.4 at 340K: -1.163697498149189 Kcal/mol
# Esw for 10.6 at 340K: -1.1218276283237851 Kcal/mol
# Esw for 10.8 at 340K: -1.084168023191516 Kcal/mol
# Esw for 11.0 at 340K: -1.048936958472469 Kcal/mol
# Esw for 11.2 at 340K: -1.0202764236627642 Kcal/mol
# Esw for 11.4 at 340K: -0.9969452469223817 Kcal/mol
# Esw for 11.6 at 340K: -0.974444798541123 Kcal/mol
# Esw for 11.8 at 340K: -0.9561780029228072 Kcal/mol
# Esw for 12.0 at 340K: -0.9372991075376701 Kcal/mol
# Esw for 12.2 at 340K: -0.917868697073508 Kcal/mol
# Esw for 12.4 at 340K: -0.8982931739345462 Kcal/mol
# Esw for 12.6 at 340K: -0.8795572362881118 Kcal/mol
# Esw for 12.8 at 340K: -0.8593009893220569 Kcal/mol
# Esw for 13.0 at 340K: -0.8404963302057173 Kcal/mol
# Esw for 13.2 at 340K: -0.8214295141972677 Kcal/mol
# Esw for 13.4 at 340K: -0.8040356647125879 Kcal/mol
# Esw for 13.6 at 340K: -0.7863064583362758 Kcal/mol
# Esw for 13.8 at 340K: -0.7691860267339748 Kcal/mol
# Esw for 14.0 at 340K: -0.752341114300252 Kcal/mol
# Esw for 14.2 at 340K: -0.7374972651875431 Kcal/mol
# Esw for 14.4 at 340K: -0.7230867482122191 Kcal/mol
# Esw for 14.6 at 340K: -0.7093516042984026 Kcal/mol
# Esw for 14.8 at 340K: -0.6968685442925031 Kcal/mol
# Esw for 15.0 at 340K: -0.6852436006059859 Kcal/mol
# Esw for 5.6 at 360K: -0.8663502384030585 Kcal/mol
# Esw for 5.8 at 360K: -1.8606964103704509 Kcal/mol
# Esw for 6.0 at 360K: -2.3512189068463365 Kcal/mol
# Esw for 6.2 at 360K: -2.584990461183912 Kcal/mol
# Esw for 6.4 at 360K: -2.6441855180532965 Kcal/mol
# Esw for 6.6 at 360K: -2.603120827940089 Kcal/mol
# Esw for 6.8 at 360K: -2.501522085078119 Kcal/mol
# Esw for 7.0 at 360K: -2.374544911493728 Kcal/mol
# Esw for 7.2 at 360K: -2.239909535088313 Kcal/mol
# Esw for 7.4 at 360K: -2.1057620856425596 Kcal/mol
# Esw for 7.6 at 360K: -1.9817945194096003 Kcal/mol
# Esw for 7.8 at 360K: -1.8686011996628673 Kcal/mol
# Esw for 8.0 at 360K: -1.7667617897786652 Kcal/mol
# Esw for 8.2 at 360K: -1.673175325471814 Kcal/mol
# Esw for 8.4 at 360K: -1.58651496304635 Kcal/mol
# Esw for 8.6 at 360K: -1.5138518437575197 Kcal/mol
# Esw for 8.8 at 360K: -1.4815952579246554 Kcal/mol
# Esw for 9.0 at 360K: -1.472637477135274 Kcal/mol
# Esw for 9.2 at 360K: -1.4536819124994398 Kcal/mol
# Esw for 9.4 at 360K: -1.4155883209939941 Kcal/mol
# Esw for 9.6 at 360K: -1.3647072759661234 Kcal/mol
# Esw for 9.8 at 360K: -1.3092365305536715 Kcal/mol
# Esw for 10.0 at 360K: -1.2549942056515797 Kcal/mol
# Esw for 10.2 at 360K: -1.2052356060207117 Kcal/mol
# Esw for 10.4 at 360K: -1.1579922137440017 Kcal/mol
# Esw for 10.6 at 360K: -1.1159253915727285 Kcal/mol
# Esw for 10.8 at 360K: -1.0782237857251096 Kcal/mol
# Esw for 11.0 at 360K: -1.0443791821629949 Kcal/mol
# Esw for 11.2 at 360K: -1.0143278215463285 Kcal/mol
# Esw for 11.4 at 360K: -0.9901082796899038 Kcal/mol
# Esw for 11.6 at 360K: -0.966692163665203 Kcal/mol
# Esw for 11.8 at 360K: -0.9465210849460365 Kcal/mol
# Esw for 12.0 at 360K: -0.9277262795718788 Kcal/mol
# Esw for 12.2 at 360K: -0.9074897598826659 Kcal/mol
# Esw for 12.4 at 360K: -0.8884745735588747 Kcal/mol
# Esw for 12.6 at 360K: -0.8690619863458184 Kcal/mol
# Esw for 12.8 at 360K: -0.8498153094058754 Kcal/mol
# Esw for 13.0 at 360K: -0.8310054356274459 Kcal/mol
# Esw for 13.2 at 360K: -0.8124493088999256 Kcal/mol
# Esw for 13.4 at 360K: -0.7951583639437227 Kcal/mol
# Esw for 13.6 at 360K: -0.777314467257549 Kcal/mol
# Esw for 13.8 at 360K: -0.7593457452878344 Kcal/mol
# Esw for 14.0 at 360K: -0.7444780503079607 Kcal/mol
# Esw for 14.2 at 360K: -0.7291247883375119 Kcal/mol
# Esw for 14.4 at 360K: -0.7143215522535238 Kcal/mol
# Esw for 14.6 at 360K: -0.7010908584219588 Kcal/mol
# Esw for 14.8 at 360K: -0.6882520263719735 Kcal/mol
# Esw for 15.0 at 360K: -0.677078358689408 Kcal/mol
